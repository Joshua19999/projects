# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df_mission_launches=pd.read_csv("mission_launches.csv", sep=",")
df_mission_launches = df_mission_launches.drop( 
    df_mission_launches.iloc[:,0:1].columns,
    axis=1
)
df_mission_launches
# Out:
#      Organisation                                           Location  \
# 0          SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1            CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2          SpaceX                      Pad A, Boca Chica, Texas, USA
# 3       Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4             ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...           ...                                                ...
# 4319      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320         AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                             Date  \
# 0     Fri Aug 07, 2020 05:12 UTC
# 1     Thu Aug 06, 2020 04:01 UTC
# 2     Tue Aug 04, 2020 23:57 UTC
# ...

# %%
meses=df_mission_launches.Date.str.split(pat="," and " ",expand=True).drop([0,2,3,4,5],axis=1)
anio=df_mission_launches.Date.str.split(pat="," and " ",expand=True).drop([0,1,2,4,5],axis=1)
df_mission_launches["Anio"]=anio.astype(int)
df_mission_launches["Meses"]=meses.astype(str)
df_mission_launches
# Out:
#      Organisation                                           Location  \
# 0          SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1            CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2          SpaceX                      Pad A, Boca Chica, Texas, USA
# 3       Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4             ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...           ...                                                ...
# 4319      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320         AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                             Date  \
# 0     Fri Aug 07, 2020 05:12 UTC
# 1     Thu Aug 06, 2020 04:01 UTC
# 2     Tue Aug 04, 2020 23:57 UTC
# ...

# %% [markdown]
# 1

# %%
aniobus=2020
df_filtrado=df_mission_launches[["Organisation","Anio"]][df_mission_launches["Anio"]==aniobus]
organizaciones=df_filtrado.Organisation.unique()
Mission_Status=df_filtrado.Organisation.value_counts()

type(Mission_Status)
# Out:
# pandas.core.series.Series

# %%
plt.figure(figsize=(16, 6))
plt.bar(organizaciones, Mission_Status,color="r")
ax = plt.subplot()
plt.title("Orgaciones con más misiones")
ax.set_xlabel('Organizaciones')  # Nombre del eje x
ax.set_ylabel('Misiones')  # Nombre del eje y
# Out:
# Text(0, 0.5, 'Misiones')

# %%
#df_mission_launches.to_csv("mission_launches.csv")

# %% [markdown]
# 2

# %%
aniosc=df_mission_launches.Anio.value_counts()

anios=aniosc.index.to_list()
aniosc=df_mission_launches.Anio.value_counts().to_list()

anios[0:3]
# Out:
# [1971, 2018, 1977]

# %%
plt.figure(figsize=(16, 6))
plt.bar(anios,aniosc,color="g")
ax = plt.subplot()
plt.title('Lanzamientos por año')  # Título
ax.set_xlabel('Años')  # Nombre del eje x
ax.set_ylabel('Lanzamientos')  # Nombre del eje y
# Out:
# Text(0, 0.5, 'Lanzamientos')

# %% [markdown]
# 3

# %%
costo=df_mission_launches.Price
tiempo=df_mission_launches.Anio
costocada=[]
tiempocada=[]
acceder=0
cada=10
while acceder<len(costo):
    # print(costo[acceder],"--->",tiempo[acceder])
    costocada.append(costo[acceder])
    tiempocada.append(tiempo[acceder])
    acceder+=cada

costo=pd.Series(costocada)
tiempo=pd.Series(tiempocada)

df_precios=pd.DataFrame()
df_precios["Precios"]=costo
df_precios["Anios"]=tiempo

df_precios=df_precios.dropna()
costo=df_precios["Precios"]
tiempo=df_precios["Anios"]
costo,tiempo
# Out:
# (0         50.0
#  1         46.0
#  2         50.0
#  3        120.0
#  4         48.5
#          ...
#  318    1,160.0
#  356    1,160.0
#  369       59.0
#  400      63.23
#  402      63.23
#  Name: Precios, Length: 111, dtype: object,
#  0      2020
#  1      2020
#  2      2020
#  3      2020
#  4      2020
#         ...
#  318    1972
#  356    1969
#  369    1968
#  400    1964
#  402    1964
#  Name: Anios, Length: 111, dtype: int32)

# %%
plt.figure(figsize=(18,12))
plt.bar(tiempo,costo,color="r")
ax = plt.subplot()
plt.title(f"Precios cada {cada} años")
ax.set_xlabel('Años')  # Nombre del eje x
ax.set_ylabel('Precios')  # Nombre del eje y
# Out:
# Text(0, 0.5, 'Precios')

# %% [markdown]
# 4

# %%
meses=df_mission_launches.Meses.value_counts()
meses=meses.index.to_list()
mesesc=df_mission_launches.Meses.value_counts().to_list()
meses ,mesesc
# Out:
# (['Dec',
#   'Jun',
#   'Apr',
#   'Oct',
#   'Aug',
#   'Sep',
#   'Mar',
#   'Jul',
#   'Feb',
#   'Nov',
#   'May',
#   'Jan'],
#  [450, 402, 383, 381, 373, 365, 353, 351, 336, 336, 326, 268])

# %%
plt.figure(figsize=(18,8))
ax = plt.subplot()
plt.bar(meses,mesesc,color="r")

plt.title("Meses con más lanzamientos")
ax.set_xlabel('Meses')  # Nombre del eje x
ax.set_ylabel('Lanzamientos')  # Nombre del eje y
# Out:
# Text(0, 0.5, 'Lanzamientos')

# %% [markdown]
# 5

# %%
misiones=df_mission_launches.Mission_Status
años=df_mission_launches.Anio
añosuni=df_mission_launches.Anio.unique().tolist()
fallosxaños=[]

for con in añosuni:
    fallos=df_mission_launches.Mission_Status[df_mission_launches.Anio==con]

    fallosxaño=fallos.value_counts().values[fallos.value_counts().index=="Failure"].astype(int)
    fallosxaños.append(fallosxaño[0])
cont=0
añosuniv=[]
fallosxañosv=[]
while cont <= 9:
    añosuniv.append(añosuni[cont])
    fallosxañosv.append(fallosxaños[cont])
    cont+=1
añosuniv,fallosxañosv
# Out:
# ([2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011],
#  [6, 6, 2, 6, 2, 3, 1, 2, 3, 1])

# %%
plt.figure(figsize=(15,8))
plt . bar(añosuniv,fallosxañosv,color="m")
ax = plt.subplot()
plt.title("Fallos por años")
ax.set_xlabel('Años')  # Nombre del eje x
ax.set_ylabel('Fallos')  # Nombre del eje y
# Out:
# Text(0, 0.5, 'Fallos')
