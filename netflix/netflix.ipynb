# %%
import pandas as pd

# %%
df_netflix=pd.read_csv("netflix1.csv", sep=",")
df_netflix.to_csv("netflix1.csv")

# %%
#1
null = df_netflix.isnull().sum()
null
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
#3
df_netflix.drop( 
    df_netflix.iloc[:,0:2].columns,
    axis=1
)
# Out:
#                                  title         director        country  \
# 0                 Dick Johnson Is Dead  Kirsten Johnson  United States
# 1                            Ganglands  Julien Leclercq         France
# 2                        Midnight Mass    Mike Flanagan  United States
# 3     Confessions of an Invisible Girl    Bruno Garotti         Brazil
# 4                              Sankofa     Haile Gerima  United States
# ...                                ...              ...            ...
# 8785                        Yunus Emre        Not Given         Turkey
# 8786                         Zak Storm        Not Given  United States
# 8787                Zindagi Gulzar Hai        Not Given       Pakistan
# 8788                              Yoko        Not Given       Pakistan
# 8789                               YOM        Not Given       Pakistan
#
#       date_added  release_year rating   duration  \
# 0      9/25/2021          2020  PG-13     90 min
# ...

# %%
#4
release_year=df_netflix.release_year
release_year,release_year.astype(float)
# Out:
# (0       2020
#  1       2021
#  2       2021
#  3       2021
#  4       1993
#          ...
#  8785    2016
#  8786    2016
#  8787    2012
#  8788    2016
#  8789    2016
#  Name: release_year, Length: 8790, dtype: int64,
#  0       2020.0
#  1       2021.0
#  2       2021.0
#  3       2021.0
#  4       1993.0
#           ...
#  8785    2016.0
#  8786    2016.0
#  8787    2012.0
#  8788    2016.0
#  8789    2016.0
#  Name: release_year, Length: 8790, dtype: float64)

# %%
#5
listed_in=df_netflix.listed_in.str.split(",", expand=True).drop([1,2], axis= 1)
listed_in
# Out:
#                              0
# 0                Documentaries
# 1               Crime TV Shows
# 2                    TV Dramas
# 3     Children & Family Movies
# 4                       Dramas
# ...                        ...
# 8785    International TV Shows
# 8786                  Kids' TV
# 8787    International TV Shows
# 8788                  Kids' TV
# 8789                  Kids' TV
#
# [8790 rows x 1 columns]
